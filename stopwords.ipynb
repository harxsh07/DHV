# %% [markdown]
# <a href="https://colab.research.google.com/github/harxsh07/DHV/blob/main/stopwords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
nltk.download("stopwords")

def remove_stop_words(string):
    stop_words = set(stopwords.words('english'))
    words = string.split()
    filtered_words = [word for word in words if word.lower() not in stop_words]
    new_string = ' '.join(filtered_words)
    return new_string, len(words) - len(filtered_words)

input_string = input("enter sentence:")
result, stop_word_count = remove_stop_words(input_string)

print("Original string:", input_string)
print("Modified string:", result)
print("Number of stop words removed:", stop_word_count)

labels = ['Stop Words', 'Non-stop Words']
count = [stop_word_count, len(input_string.split()) - stop_word_count]

plt.bar(labels, count, color=['blue', 'green'])
plt.xlabel('Word Type')
plt.ylabel('Count')
plt.title('Stop Word vs Non-stop Word Count')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# enter sentence:The quick brown fox jumps over the lazy dog while it's raining heavily outside, and despite the chilly weather, the fox continues its journey through the dense forest, encountering various obstacles along the way such as fallen trees and slippery paths, but it perseveres with determination, fueled by its instinctual drive to survive and thrive in the harsh wilderness, where every moment presents a new challenge and opportunity for growth, and though the journey may seem endless and daunting, the fox remains undeterred, relying on its keen senses and cunning intellect to navigate the treacherous terrain and emerge victorious.
# Original string: The quick brown fox jumps over the lazy dog while it's raining heavily outside, and despite the chilly weather, the fox continues its journey through the dense forest, encountering various obstacles along the way such as fallen trees and slippery paths, but it perseveres with determination, fueled by its instinctual drive to survive and thrive in the harsh wilderness, where every moment presents a new challenge and opportunity for growth, and though the journey may seem endless and daunting, the fox remains undeterred, relying on its keen senses and cunning intellect to navigate the treacherous terrain and emerge victorious.
# Modified string: quick brown fox jumps lazy dog raining heavily outside, despite chilly weather, fox continues journey dense forest, encountering various obstacles along way fallen trees slippery paths, perseveres determination, fueled instinctual drive survive thrive harsh wilderness, every moment presents new challenge opportunity growth, though journey may seem endless daunting, fox remains undeterred, relying keen senses cunning intellect navigate treacherous terrain emerge victorious.
# Number of stop words removed: 38
